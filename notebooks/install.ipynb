# %%
pip install apache-beam[interactive]

# %%
pip install tensorflow_model_analysis

# %%
pip install pydot

# %%
pip install graphviz

# %%
pip install azureml-train-automl-runtime==1.25.0

# %%
pip install azureml.automl.runtime==1.26.0

# %%
pip install azureml-train-automl==1.26.0

# %%
pip install azureml.core==1.24.0

# %%
pip install azureml-train-automl==1.24.0

# %%
pip install azureml-train-automl-runtime==1.24.0

# %%
pip install azureml-core==1.26.0

# %%
pip install --upgrade azureml-core
# Out:
# Requirement already up-to-date: azureml-core in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.28.0)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade azureml-train-core
# Out:
# Requirement already up-to-date: azureml-train-core in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.28.0)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade azureml-train
# Out:
# Requirement already up-to-date: azureml-train in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.28.0)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade azureml-sdk
# Out:
# Requirement already up-to-date: azureml-sdk in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.28.0)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade azureml-contrib-pipeline-steps
# Out:
# ...
#   Attempting uninstall: azureml-contrib-pipeline-steps
#     Found existing installation: azureml-contrib-pipeline-steps 1.26.0
#     Uninstalling azureml-contrib-pipeline-steps-1.26.0:
#       Successfully uninstalled azureml-contrib-pipeline-steps-1.26.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade azureml-cli-common
# Out:
# ...
#   Attempting uninstall: azureml-cli-common
#     Found existing installation: azureml-cli-common 1.26.0
#     Uninstalling azureml-cli-common-1.26.0:
#       Successfully uninstalled azureml-cli-common-1.26.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade azureml-datadrift
# Out:
# Requirement already up-to-date: azureml-datadrift in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.28.0)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade azureml-train-automl
# Out:
# Requirement already up-to-date: azureml-train-automl in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.28.0)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.version)
# Out:
# 3.6.9 |Anaconda, Inc.| (default, Jul 30 2019, 19:07:31)
# [GCC 7.3.0]
